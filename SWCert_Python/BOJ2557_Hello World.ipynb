# %% [markdown]
# ### BOJ2557 Hello World
# [링크] https://www.acmicpc.net/problem/2557
#
# [문제]
# Hello World!를 출력하시오.
#
# [입력]
# 없음
#
# [출력]
# Hello World!를 출력하시오.
#
# [예제 입력 1]
#
# [예제 출력 1]
# Hello World!
#
# [MEMO]

# %%
print("Hello World!")
# Out:
# Hello World!
