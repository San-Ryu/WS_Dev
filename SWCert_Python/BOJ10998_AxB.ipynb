# %% [markdown]
# ### BOJ10998 AxB
# [링크] https://www.acmicpc.net/problem/10998
#
# [문제]
# 두 정수 A와 B를 입력받은 다음, AxB를 출력하는 프로그램을 작성하시오.
#
# [입력]
# 첫째 줄에 A와 B가 주어진다. (0 < A, B < 10)
#
# [출력]
# 첫째 줄에 A×B를 출력한다.
#
# [예제 입력 1]
# 1 2
#
# [예제 출력 1]
# 2
#
# [예제 입력 1]
# 3 4
#
# [예제 출력 1]
# 12
#
# [MEMO]

# %%
import sys
sys.stdin = open("Input/Input_BOJ10989.txt", "r")

N = int(sys.stdin.readline())
ls_cnt = [0] * 10000

## List는 생성하지 않는다.
# ls_num = [int(sys.stdin.readline()) for _ in range(N)]
# ls_num.sort()

for _ in range(N): ls_cnt[int(sys.stdin.readline()) - 1] += 1
    
for i in range(len(ls_cnt)): 
    for _ in range(ls_cnt[i]): sys.stdout.write((str(i + 1) + '\n'))
# Out:
# 1
# 1
# 2
# 2
# 3
# 3
# 4
# 5
# 5
# 7

# %%
a, b = map(int, input().split())
print(a * b)
# Out:
# 12
