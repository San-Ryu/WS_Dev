# %% [raw]
# ### BOJ10430 나머지
# [링크] https://www.acmicpc.net/problem/10430
#
# [문제]
# (A+B)%C는 ((A%C) + (B%C))%C 와 같을까?
#
# (A×B)%C는 ((A%C) × (B%C))%C 와 같을까?
#
# 세 수 A, B, C가 주어졌을 때, 위의 네 가지 값을 구하는 프로그램을 작성하시오.
#
# [입력]
# 첫째 줄에 A, B, C가 순서대로 주어진다. (2 ≤ A, B, C ≤ 10000)
#
# [출력]
# 첫째 줄에 (A+B)%C, 둘째 줄에 ((A%C) + (B%C))%C, 셋째 줄에 (A×B)%C, 넷째 줄에 ((A%C) × (B%C))%C를 출력한다.
#
# [예제 입력 1]
# 5 8 4
#
# [예제 출력 1]
# 1
# 1
# 0
# 0
#
# [MEMO]
# 문제 자체는 단순한 편이다. 따로 풀이 과정이 필요 없을 정도.
# 주의 : 수식을 대충 읽으면 오답 위험#%% md
# ### BOJ10430 나머지
# [링크] https://www.acmicpc.net/problem/10430
#
# [문제]
# (A+B)%C는 ((A%C) + (B%C))%C 와 같을까?
#
# (A×B)%C는 ((A%C) × (B%C))%C 와 같을까?
#
# 세 수 A, B, C가 주어졌을 때, 위의 네 가지 값을 구하는 프로그램을 작성하시오.
#
# [입력]
# 첫째 줄에 A, B, C가 순서대로 주어진다. (2 ≤ A, B, C ≤ 10000)
#
# [출력]
# 첫째 줄에 (A+B)%C, 둘째 줄에 ((A%C) + (B%C))%C, 셋째 줄에 (A×B)%C, 넷째 줄에 ((A%C) × (B%C))%C를 출력한다.
#
# [예제 입력 1]
# 5 8 4
#
# [예제 출력 1]
# 1
# 1
# 0
# 0
#
# [MEMO]
# 문제 자체는 단순한 편이다. 따로 풀이 과정이 필요 없을 정도.
# 주의 : 수식을 대충 읽으면 오답 위험

# %%
a, b, c = map(int, input().split())

print((a+b)%c)
print(((a%c)+(b%c))%c)
print((a*b)%c)
print(((a%c)*(b%c))%c)

''' 오답
a, b, c = input().split()
a = int(a)
b = int(b)
c = int(c)
부분에 비해 더욱 효율적이지만, 수학 수식이 틀렸다.
다음부터는 문제를 더 잘 읽어야 한다.

a, b, c = map(int, input().split())

print((a+b)%c)
print(((a%b)+(b%c))%c)
print((a*b)%c)
print(((a%b)*(b%c))%c)
'''
# Out:
# 1
# 1
# 0
# 0
# ' 오답\na, b, c = input().split()\na = int(a)\nb = int(b)\nc = int(c)\n부분에 비해 더욱 효율적이지만, 수학 수식이 틀렸다.\n다음부터는 문제를 더 잘 읽어야 한다.\n\na, b, c = map(int, input().split())\n\nprint((a+b)%c)\nprint(((a%b)+(b%c))%c)\nprint((a*b)%c)\nprint(((a%b)*(b%c))%c)\n'
